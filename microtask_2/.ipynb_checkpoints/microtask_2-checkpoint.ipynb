# %%
from datetime import datetime
from pprint import pprint
from elasticsearch_dsl import Search

import elasticsearch as ES
import subprocess
import calendar
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Url for the git repo to analyze
org_name = "grimoirelab"
repo_name = "perceval"
#url at which Elasticsearch must be running
es_url = "http://localhost:9200"

# Directory for letting Perceval clone the git repo
raw_index = "github_raw"
enriched_index = "github"

# ElasticSearch instance (url)
es = ES.Elasticsearch([es_url])

#verification token to avoid problems regarding unauthenticated access to the GitHub API
token = '36b6d5dd8be1dfb2f45ae6b903b1f83263df8c86'

# %%
#This takes sometime 
subprocess.run(['p2o.py', '--enrich', '--index', raw_index,
      '--index-enrich', enriched_index, '-e', es_url,
      '--no_inc', '--debug', 'github', org_name , repo_name,
      '-t',  token, '--sleep-for-rate'])
print ('Done!')
# Out:
# Done!

# %%
response=es.search(index=enriched_index)
total_commits = (response['hits']['total'])
response = es.search(index=enriched_index, body={"size":total_commits})
t = []
for x in range(total_commits):
         t.append(response['hits']['hits'][x]['_source'])
pprint (t)
# Out:
# [{'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': 'sduenas',
#   'assignee_name': 'Santiago Dueñas',
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2016-01-04T01:32:26Z',
#   'created_at': '2015-12-04T17:48:34Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2015-12-04T17:48:34+00:00',
#   'id': 120451821,
#   'id_in_repo': '2',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:25.724253',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:36:36.425836+00:00',
#   'metadata__updated_on': '2016-01-21T14:01:54+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 30.32,
#   'time_to_close_days': 30.32,
#   'title': '[github] Add github backend for perceval.',
#   'title_analyzed': '[github] Add github backend for perceval.',
#   'updated_at': '2016-01-21T14:01:54Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/2',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/2',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': 'fc9da7fc60cd6406e882ef5a4d819ee2b30d7215'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2016-01-26T19:26:43Z',
#   'created_at': '2016-01-21T19:57:25Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-01-21T19:57:25+00:00',
#   'id': 128006801,
#   'id_in_repo': '7',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:25.727177',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:36:38.620254+00:00',
#   'metadata__updated_on': '2016-01-26T19:26:43+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 4.98,
#   'time_to_close_days': 4.98,
#   'title': '[github] Add to issues user data from the GitHub User API (email, '
#            'company ...)',
#   'title_analyzed': '[github] Add to issues user data from the GitHub User API '
#                     '(email, company ...)',
#   'updated_at': '2016-01-26T19:26:43Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/7',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/7',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': 'f8947128927d2435f51c97d982ec54c2716aa802'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alberto Martín',
#   'closed_at': '2016-02-10T17:32:01Z',
#   'created_at': '2016-02-10T16:52:06Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-02-10T16:52:06+00:00',
#   'id': 132756323,
#   'id_in_repo': '11',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:26.515294',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:36:44.067227+00:00',
#   'metadata__updated_on': '2016-03-03T13:03:08+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.03,
#   'time_to_close_days': 0.03,
#   'title': '[docker] Add Docker support for Perceval',
#   'title_analyzed': '[docker] Add Docker support for Perceval',
#   'updated_at': '2016-03-03T13:03:08Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/11',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/11',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid',
#   'user_login': 'albertinisg',
#   'user_name': 'Alberto Martín',
#   'user_org': '@Bitergia ',
#   'uuid': '56fa70880e415f53500e59ac5cf684f1470dd3fa'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Jesus M. Gonzalez-Barahona',
#   'closed_at': '2016-07-11T10:25:56Z',
#   'created_at': '2016-06-23T23:34:59Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-06-23T23:34:59+00:00',
#   'id': 162046481,
#   'id_in_repo': '45',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.227383',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:37:50.325888+00:00',
#   'metadata__updated_on': '2016-07-11T10:26:38+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 17.45,
#   'time_to_close_days': 17.45,
#   'title': '[Git] Adding support for fetching branches.',
#   'title_analyzed': '[Git] Adding support for fetching branches.',
#   'updated_at': '2016-07-11T10:26:38Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/45',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/45',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'jgbarah',
#   'user_name': 'Jesus M. Gonzalez-Barahona',
#   'user_org': None,
#   'uuid': 'b3c7bef69a8a7f36e1c7513d130b2d90144bc964'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2016-07-18T11:49:10Z',
#   'created_at': '2016-07-15T07:20:29Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-07-15T07:20:29+00:00',
#   'id': 165726399,
#   'id_in_repo': '51',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.731301',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:37:58.625240+00:00',
#   'metadata__updated_on': '2016-07-18T11:49:10+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 3.19,
#   'time_to_close_days': 3.19,
#   'title': '[gerrit] Fix #50',
#   'title_analyzed': '[gerrit] Fix #50',
#   'updated_at': '2016-07-18T11:49:10Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/51',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/51',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': 'fa8d992494bc7f00d0db7e436820676224b7a2e4'},
#  {'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': 'sduenas',
#   'assignee_name': 'Santiago Dueñas',
#   'assignee_org': None,
#   'author_name': 'Daniel Izquierdo Cortazar',
#   'closed_at': '2016-09-12T12:22:14Z',
#   'created_at': '2016-09-09T16:30:32Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-09-09T16:30:32+00:00',
#   'id': 176052057,
#   'id_in_repo': '57',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'bug;;mbox;;',
#   'metadata__enriched_on': '2018-03-04T17:36:27.733920',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:09.840997+00:00',
#   'metadata__updated_on': '2016-09-12T12:25:17+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 2.83,
#   'time_to_close_days': 2.83,
#   'title': '[mbox] Error when parsing a specific date',
#   'title_analyzed': '[mbox] Error when parsing a specific date',
#   'updated_at': '2016-09-12T12:25:17Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/57',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/57',
#   'user_domain': 'bitergia.com',
#   'user_email': 'dizquierdo@bitergia.com',
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'dicortazar',
#   'user_name': 'Daniel Izquierdo Cortazar',
#   'user_org': 'Bitergia',
#   'uuid': 'ceb5c17f1913689416c1bc8dcb8c0a4e590835f6'},
#  {'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': 'sduenas',
#   'assignee_name': 'Santiago Dueñas',
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2016-09-25T18:57:45Z',
#   'created_at': '2016-09-21T13:17:48Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-09-21T13:17:48+00:00',
#   'id': 178344079,
#   'id_in_repo': '64',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'enhancement;;phabricator;;',
#   'metadata__enriched_on': '2018-03-04T17:36:27.736259',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:16.339099+00:00',
#   'metadata__updated_on': '2016-09-25T18:57:45+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 4.24,
#   'time_to_close_days': 4.24,
#   'title': "[phabricator] Maniphest items don't include tags",
#   'title_analyzed': "[phabricator] Maniphest items don't include tags",
#   'updated_at': '2016-09-25T18:57:45Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/64',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/64',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '01245a7e801b4ede8ed803c686ed90e62f90b093'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Jose Miguel',
#   'closed_at': '2016-10-03T13:36:46Z',
#   'created_at': '2016-09-27T09:48:20Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-09-27T09:48:20+00:00',
#   'id': 179446239,
#   'id_in_repo': '67',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.848373',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:25.421478+00:00',
#   'metadata__updated_on': '2016-10-03T13:36:46+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 6.16,
#   'time_to_close_days': 6.16,
#   'title': 'To work with Windows 10',
#   'title_analyzed': 'To work with Windows 10',
#   'updated_at': '2016-10-03T13:36:46Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/67',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/67',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'shongoku',
#   'user_name': 'Jose Miguel',
#   'user_org': None,
#   'uuid': 'cc5c2c7702ed8698d09ed02f0fce38a910438511'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2016-10-18T14:18:51Z',
#   'created_at': '2016-10-18T06:04:08Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-10-18T06:04:08+00:00',
#   'id': 183597665,
#   'id_in_repo': '78',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.850407',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:30.547087+00:00',
#   'metadata__updated_on': '2016-10-18T14:19:01+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.34,
#   'time_to_close_days': 0.34,
#   'title': '[kitsune] Add error management when the kitsune sever fails',
#   'title_analyzed': '[kitsune] Add error management when the kitsune sever '
#                     'fails',
#   'updated_at': '2016-10-18T14:19:01Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/78',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/78',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '72d73e3ae2f4ff658ba1994c77f096589ae292e8'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2016-10-18T16:13:04Z',
#   'created_at': '2016-10-18T15:34:59Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-10-18T15:34:59+00:00',
#   'id': 183722798,
#   'id_in_repo': '79',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.850885',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:32.086423+00:00',
#   'metadata__updated_on': '2016-10-18T16:13:16+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.03,
#   'time_to_close_days': 0.03,
#   'title': '[jenkins] Add blacklist support to jenkins backend',
#   'title_analyzed': '[jenkins] Add blacklist support to jenkins backend',
#   'updated_at': '2016-10-18T16:13:16Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/79',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/79',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '3056ead1c9bb814fb207a5b0b33f26e90e5afe0d'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Jose Miguel',
#   'closed_at': '2016-10-24T20:20:07Z',
#   'created_at': '2016-10-10T21:02:31Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-10-10T21:02:31+00:00',
#   'id': 182114967,
#   'id_in_repo': '75',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.853039',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:38.105115+00:00',
#   'metadata__updated_on': '2016-10-24T20:20:07+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 13.97,
#   'time_to_close_days': 13.97,
#   'title': 'Added the tool setuptools',
#   'title_analyzed': 'Added the tool setuptools',
#   'updated_at': '2016-10-24T20:20:07Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/75',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/75',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'shongoku',
#   'user_name': 'Jose Miguel',
#   'user_org': None,
#   'uuid': 'c946e634e14dc1d13c3a11bf8540f8e9da65ea1c'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Jesus M. Gonzalez-Barahona',
#   'closed_at': '2016-10-26T11:16:22Z',
#   'created_at': '2016-09-28T12:32:26Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-09-28T12:32:26+00:00',
#   'id': 179759644,
#   'id_in_repo': '68',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:27.853877',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:40.181912+00:00',
#   'metadata__updated_on': '2016-10-26T11:16:22+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 27.95,
#   'time_to_close_days': 27.95,
#   'title': 'Add MANIFEST.in to avoid problems when building sdist package.',
#   'title_analyzed': 'Add MANIFEST.in to avoid problems when building sdist '
#                     'package.',
#   'updated_at': '2016-10-26T11:16:22Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/68',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/68',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'jgbarah',
#   'user_name': 'Jesus M. Gonzalez-Barahona',
#   'user_org': None,
#   'uuid': '0e5499cd850a2757b17ac7ada3361dcfb4daed21'},
#  {'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': 'sduenas',
#   'assignee_name': 'Santiago Dueñas',
#   'assignee_org': None,
#   'author_name': 'Daniel Izquierdo Cortazar',
#   'closed_at': '2016-10-28T12:20:49Z',
#   'created_at': '2016-10-28T10:19:44Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-10-28T10:19:44+00:00',
#   'id': 185888619,
#   'id_in_repo': '89',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'bug;;jira;;',
#   'metadata__enriched_on': '2018-03-04T17:36:27.854719',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:42.573433+00:00',
#   'metadata__updated_on': '2016-10-28T12:20:49+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.08,
#   'time_to_close_days': 0.08,
#   'title': '[jira] The Jira backend starts from the newest issues instead of '
#            'starting from the oldest ones',
#   'title_analyzed': '[jira] The Jira backend starts from the newest issues '
#                     'instead of starting from the oldest ones',
#   'updated_at': '2016-10-28T12:20:49Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/89',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/89',
#   'user_domain': 'bitergia.com',
#   'user_email': 'dizquierdo@bitergia.com',
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'dicortazar',
#   'user_name': 'Daniel Izquierdo Cortazar',
#   'user_org': 'Bitergia',
#   'uuid': '4d773358887fa58d64ba60d62cc5d250a9f546ab'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alberto Martín',
#   'closed_at': '2016-12-14T10:26:38Z',
#   'created_at': '2016-12-14T09:51:35Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-12-14T09:51:35+00:00',
#   'id': 195485551,
#   'id_in_repo': '100',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': 'bug;;',
#   'metadata__enriched_on': '2018-03-04T17:36:28.442530',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:38:59.146035+00:00',
#   'metadata__updated_on': '2016-12-14T10:26:38+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.02,
#   'time_to_close_days': 0.02,
#   'title': '[docker] Avoid git package purge',
#   'title_analyzed': '[docker] Avoid git package purge',
#   'updated_at': '2016-12-14T10:26:38Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/100',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/100',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid',
#   'user_login': 'albertinisg',
#   'user_name': 'Alberto Martín',
#   'user_org': '@Bitergia ',
#   'uuid': 'ef6b2f814568e5a748115203c4691db631a9a51c'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Stephan Barth',
#   'closed_at': '2017-01-09T17:17:03Z',
#   'created_at': '2017-01-09T15:55:29Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-01-09T15:55:29+00:00',
#   'id': 199588155,
#   'id_in_repo': '106',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:29.837148',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:11.999528+00:00',
#   'metadata__updated_on': '2017-01-09T17:18:05+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.06,
#   'time_to_close_days': 0.06,
#   'title': 'fixed FSF address',
#   'title_analyzed': 'fixed FSF address',
#   'updated_at': '2017-01-09T17:18:05Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/106',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/106',
#   'user_email': None,
#   'user_geolocation': {'lat': 49.4521018, 'lon': 11.0766654},
#   'user_location': 'Nuremberg',
#   'user_login': 'celan',
#   'user_name': 'Stephan Barth',
#   'user_org': 'SUSE',
#   'uuid': '2969b75ea7cd942c6611f68e1648d3eda3b4fe95'},
#  {'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': 'sduenas',
#   'assignee_name': 'Santiago Dueñas',
#   'assignee_org': None,
#   'author_name': 'Alberto Martín',
#   'closed_at': '2017-01-12T17:47:38Z',
#   'created_at': '2016-12-23T10:59:36Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-12-23T10:59:36+00:00',
#   'id': 197350421,
#   'id_in_repo': '102',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'bug;;git;;',
#   'metadata__enriched_on': '2018-03-04T17:36:29.837997',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:15.768350+00:00',
#   'metadata__updated_on': '2017-01-12T17:48:52+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 20.28,
#   'time_to_close_days': 20.28,
#   'title': '[git] Error when trying to fetch an empty repository',
#   'title_analyzed': '[git] Error when trying to fetch an empty repository',
#   'updated_at': '2017-01-12T17:48:52Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/102',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/102',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid',
#   'user_login': 'albertinisg',
#   'user_name': 'Alberto Martín',
#   'user_org': '@Bitergia ',
#   'uuid': '1365ce12331ef326d97ea9e982623dda3cda2a39'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-01-19T11:17:46Z',
#   'created_at': '2017-01-16T22:25:01Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-01-16T22:25:01+00:00',
#   'id': 201131483,
#   'id_in_repo': '108',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'enhancement;;',
#   'metadata__enriched_on': '2018-03-04T17:36:29.838966',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:18.603676+00:00',
#   'metadata__updated_on': '2017-01-19T11:17:46+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 2.54,
#   'time_to_close_days': 2.54,
#   'title': 'Add perceval current version to command line help',
#   'title_analyzed': 'Add perceval current version to command line help',
#   'updated_at': '2017-01-19T11:17:46Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/108',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/108',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '858c20b6bc7c56ff0852822ca60efa3acb531220'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-01-24T18:25:18Z',
#   'created_at': '2017-01-19T10:43:59Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-01-19T10:43:59+00:00',
#   'id': 201823447,
#   'id_in_repo': '111',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'invalid;;',
#   'metadata__enriched_on': '2018-03-04T17:36:29.887729',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:23.295396+00:00',
#   'metadata__updated_on': '2017-01-24T18:25:18+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 5.32,
#   'time_to_close_days': 5.32,
#   'title': 'bugzillarest must use api token for auth',
#   'title_analyzed': 'bugzillarest must use api token for auth',
#   'updated_at': '2017-01-24T18:25:18Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/111',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/111',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '0a8fc2a0cd3a8da524565300e9a5c3e921f56923'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-01-27T19:22:33Z',
#   'created_at': '2017-01-27T18:53:45Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-01-27T18:53:45+00:00',
#   'id': 203711610,
#   'id_in_repo': '117',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:29.889550',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:28.486717+00:00',
#   'metadata__updated_on': '2017-01-27T19:22:33+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.02,
#   'time_to_close_days': 0.02,
#   'title': "[gerrit] Use 'number' instead 'id' as unique identifier for a "
#            'review',
#   'title_analyzed': "[gerrit] Use 'number' instead 'id' as unique identifier "
#                     'for a review',
#   'updated_at': '2017-01-27T19:22:33Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/117',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/117',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': 'bfda7d8b53c5030af50a2eba62550359971a2a06'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-03-02T09:51:49Z',
#   'created_at': '2017-02-28T05:33:10Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-02-28T05:33:10+00:00',
#   'id': 210691361,
#   'id_in_repo': '121',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:29.891797',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:41.711463+00:00',
#   'metadata__updated_on': '2017-03-02T09:51:49+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 2.18,
#   'time_to_close_days': 2.18,
#   'title': '[github] Manage 404 not found error when getting the public github '
#            'orgs for a login',
#   'title_analyzed': '[github] Manage 404 not found error when getting the '
#                     'public github orgs for a login',
#   'updated_at': '2017-03-02T09:51:49Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/121',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/121',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '77a42463d5d0a34b1d58006263b85909a9788b52'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-03-27T10:48:58Z',
#   'created_at': '2017-03-23T22:28:10Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-03-23T22:28:10+00:00',
#   'id': 216591488,
#   'id_in_repo': '130',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:29.895792',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:39:51.677650+00:00',
#   'metadata__updated_on': '2017-03-27T10:48:58+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 3.51,
#   'time_to_close_days': 3.51,
#   'title': '[rss] Add User-Agent header in RSS request so wordpress.com blog '
#            'sites return the data',
#   'title_analyzed': '[rss] Add User-Agent header in RSS request so '
#                     'wordpress.com blog sites return the data',
#   'updated_at': '2017-03-27T10:48:58Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/130',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/130',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '6371c0112a9695fb2b7cd99c9ea9fb622758bfaf'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Jesus M. Gonzalez-Barahona',
#   'closed_at': '2017-08-07T15:41:12Z',
#   'created_at': '2017-08-05T17:16:38Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-08-05T17:16:38+00:00',
#   'id': 248196921,
#   'id_in_repo': '147',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:31.197632',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:40:12.302018+00:00',
#   'metadata__updated_on': '2017-08-07T15:41:26+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 1.93,
#   'time_to_close_days': 1.93,
#   'title': 'Add badge for pypi version',
#   'title_analyzed': 'Add badge for pypi version',
#   'updated_at': '2017-08-07T15:41:26Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/147',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/147',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'jgbarah',
#   'user_name': 'Jesus M. Gonzalez-Barahona',
#   'user_org': None,
#   'uuid': 'ff754c2981e13cc31c413c26f4787c559f111a87'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': '2017-09-13T09:10:37Z',
#   'created_at': '2017-09-13T08:10:25Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-09-13T08:10:25+00:00',
#   'id': 257292903,
#   'id_in_repo': '153',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:31.201445',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:40:19.995877+00:00',
#   'metadata__updated_on': '2017-09-13T09:11:05+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.04,
#   'time_to_close_days': 0.04,
#   'title': '[github] Add assignees data',
#   'title_analyzed': '[github] Add assignees data',
#   'updated_at': '2017-09-13T09:11:05Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/153',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/153',
#   'user_domain': 'bitergia.com',
#   'user_email': 'valcos@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'valeriocos',
#   'user_name': 'valerio',
#   'user_org': '@Bitergia ',
#   'uuid': '008034ca3fab9f2d63b86da51f9c5ab3ec32b1fb'},
#  {'assignee_domain': 'bitergia.com',
#   'assignee_email': 'acs@bitergia.com',
#   'assignee_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'assignee_location': 'Getafe, Madrid, Spain',
#   'assignee_login': 'acs',
#   'assignee_name': 'Alvaro del Castillo',
#   'assignee_org': 'Bitergia',
#   'author_name': 'Manrique Lopez',
#   'closed_at': None,
#   'created_at': '2016-08-18T08:05:43Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2016-08-18T08:05:43+00:00',
#   'id': 171841150,
#   'id_in_repo': '53',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'enhancement;;github;;',
#   'metadata__enriched_on': '2018-03-04T17:36:31.204076',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:40:27.084826+00:00',
#   'metadata__updated_on': '2017-09-15T08:50:54+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 563.4,
#   'time_to_close_days': None,
#   'title': '[github] Get information extra information about issues and pull '
#            'requests',
#   'title_analyzed': '[github] Get information extra information about issues '
#                     'and pull requests',
#   'updated_at': '2017-09-15T08:50:54Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/53',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/53',
#   'user_email': None,
#   'user_geolocation': {'lat': 40.2902056, 'lon': -3.8035477},
#   'user_location': 'Fuenlabrada, Spain',
#   'user_login': 'jsmanrique',
#   'user_name': 'Manrique Lopez',
#   'user_org': 'Bitergia',
#   'uuid': '2996c283cdacd29a5a8458b0a14b3083f4fd1b4b'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': '2017-10-25T17:20:44Z',
#   'created_at': '2017-10-24T19:44:23Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-10-24T19:44:23+00:00',
#   'id': 268161621,
#   'id_in_repo': '188',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:31.212764',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:40:48.042522+00:00',
#   'metadata__updated_on': '2017-10-25T17:20:44+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.9,
#   'time_to_close_days': 0.9,
#   'title': '[tests] Organize test folders',
#   'title_analyzed': '[tests] Organize test folders',
#   'updated_at': '2017-10-25T17:20:44Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/188',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/188',
#   'user_domain': 'bitergia.com',
#   'user_email': 'valcos@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'valeriocos',
#   'user_name': 'valerio',
#   'user_org': '@Bitergia ',
#   'uuid': 'b189adfe746236181cef12090e1b84260e9b2387'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'David Pose Fernández',
#   'closed_at': '2017-11-03T07:07:32Z',
#   'created_at': '2017-10-31T15:57:12Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-10-31T15:57:12+00:00',
#   'id': 270014733,
#   'id_in_repo': '192',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:31.213768',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:40:50.942738+00:00',
#   'metadata__updated_on': '2017-11-03T07:07:32+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 2.63,
#   'time_to_close_days': 2.63,
#   'title': '[github] Add GitHub Enterprise support',
#   'title_analyzed': '[github] Add GitHub Enterprise support',
#   'updated_at': '2017-11-03T07:07:32Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/192',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/192',
#   'user_domain': 'bitergia.com',
#   'user_email': 'dpose@bitergia.com',
#   'user_geolocation': {'lat': 40.46366700000001, 'lon': -3.74922},
#   'user_location': 'Spain',
#   'user_login': 'dpose',
#   'user_name': 'David Pose Fernández',
#   'user_org': None,
#   'uuid': '5049725163bc4fa5dd492bf37cce64896b3af035'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': '2017-11-28T17:08:51Z',
#   'created_at': '2017-11-28T12:57:11Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-11-28T12:57:11+00:00',
#   'id': 277375106,
#   'id_in_repo': '218',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:31.223422',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:41:11.292873+00:00',
#   'metadata__updated_on': '2017-11-28T17:08:51+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.17,
#   'time_to_close_days': 0.17,
#   'title': '[jenkins] Handle SSL EOF error',
#   'title_analyzed': '[jenkins] Handle SSL EOF error',
#   'updated_at': '2017-11-28T17:08:51Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/218',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/218',
#   'user_domain': 'bitergia.com',
#   'user_email': 'valcos@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'valeriocos',
#   'user_name': 'valerio',
#   'user_org': '@Bitergia ',
#   'uuid': '5c2c09f85ea7e983d0012b8f3b330113d2eea3a1'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Luis Cañas-Díaz',
#   'closed_at': None,
#   'created_at': '2017-11-30T17:40:49Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-11-30T17:40:49+00:00',
#   'id': 278208899,
#   'id_in_repo': '229',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'gerrit;;question;;',
#   'metadata__enriched_on': '2018-03-04T17:36:32.000442',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:41:26.020882+00:00',
#   'metadata__updated_on': '2017-12-01T13:57:44+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 94.0,
#   'time_to_close_days': None,
#   'title': 'Gerrit incremental mode is not working when process is interrupted',
#   'title_analyzed': 'Gerrit incremental mode is not working when process is '
#                     'interrupted',
#   'updated_at': '2017-12-01T13:57:44Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/229',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/229',
#   'user_domain': 'bitergia.com',
#   'user_email': 'lcanas@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid',
#   'user_login': 'sanacl',
#   'user_name': 'Luis Cañas-Díaz',
#   'user_org': 'Bitergia',
#   'uuid': '2bc8b8bb637e8acb28b5a82f5097a5023adb47e1'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': '2017-12-03T16:24:08Z',
#   'created_at': '2017-12-01T11:03:10Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-12-01T11:03:10+00:00',
#   'id': 278431219,
#   'id_in_repo': '241',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:32.001399',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:41:27.149483+00:00',
#   'metadata__updated_on': '2017-12-03T16:24:08+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 2.22,
#   'time_to_close_days': 2.22,
#   'title': '[telegram] Apply generic HTTP client to Telegram',
#   'title_analyzed': '[telegram] Apply generic HTTP client to Telegram',
#   'updated_at': '2017-12-03T16:24:08Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/241',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/241',
#   'user_domain': 'bitergia.com',
# ...
#   'grimoire_creation_date': '2017-09-19T21:52:22+00:00',
#   'id': 258975927,
#   'id_in_repo': '160',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:35.037317',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:44:28.368434+00:00',
#   'metadata__updated_on': '2018-02-13T23:12:16+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 165.82,
#   'time_to_close_days': None,
#   'title': 'Support GitHub v4 API',
#   'title_analyzed': 'Support GitHub v4 API',
#   'updated_at': '2018-02-13T23:12:16Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/160',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/160',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'jgbarah',
#   'user_name': 'Jesus M. Gonzalez-Barahona',
#   'user_org': None,
#   'uuid': '4787519ae24aef7777303fd9bbae77f9728d47eb'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alberto Martín',
#   'closed_at': '2017-10-16T19:13:11Z',
#   'created_at': '2017-10-11T12:24:04Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-10-11T12:24:04+00:00',
#   'id': 264565701,
#   'id_in_repo': '178',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'bug;;phabricator;;',
#   'metadata__enriched_on': '2018-03-04T17:36:35.063400',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:44:34.868246+00:00',
#   'metadata__updated_on': '2018-02-13T23:12:17+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 5.28,
#   'time_to_close_days': 5.28,
#   'title': '[phabricator] Error retrieving Phabricator issues',
#   'title_analyzed': '[phabricator] Error retrieving Phabricator issues',
#   'updated_at': '2018-02-13T23:12:17Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/178',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/178',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid',
#   'user_login': 'albertinisg',
#   'user_name': 'Alberto Martín',
#   'user_org': '@Bitergia ',
#   'uuid': '1eee0763e590adfc424c4161a3debca0b65623f1'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-10-30T10:15:59Z',
#   'created_at': '2017-10-16T10:48:08Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-10-16T10:48:08+00:00',
#   'id': 265725970,
#   'id_in_repo': '180',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'confluence;;',
#   'metadata__enriched_on': '2018-03-04T17:36:35.063923',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:44:36.743121+00:00',
#   'metadata__updated_on': '2018-02-13T23:12:17+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 13.98,
#   'time_to_close_days': 13.98,
#   'title': '[confluence] Error fetching data from https://wiki.open-o.org',
#   'title_analyzed': '[confluence] Error fetching data from '
#                     'https://wiki.open-o.org',
#   'updated_at': '2018-02-13T23:12:17Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/180',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/180',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '9e55c46aac4646c970f9a5a910d51a4ded9a0f8e'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alvaro del Castillo',
#   'closed_at': '2017-11-08T18:46:02Z',
#   'created_at': '2017-10-16T17:34:48Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-10-16T17:34:48+00:00',
#   'id': 265852168,
#   'id_in_repo': '183',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'meetup;;',
#   'metadata__enriched_on': '2018-03-04T17:36:35.065394',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:44:42.454169+00:00',
#   'metadata__updated_on': '2018-02-13T23:12:17+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 23.05,
#   'time_to_close_days': 23.05,
#   'title': '[meetup] Meetup rate limit exceeded; 4.0 seconds to rate reset',
#   'title_analyzed': '[meetup] Meetup rate limit exceeded; 4.0 seconds to rate '
#                     'reset',
#   'updated_at': '2018-02-13T23:12:17Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/183',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/183',
#   'user_domain': 'bitergia.com',
#   'user_email': 'acs@bitergia.com',
#   'user_geolocation': {'lat': 40.3082504, 'lon': -3.7323934},
#   'user_location': 'Getafe, Madrid, Spain',
#   'user_login': 'acs',
#   'user_name': 'Alvaro del Castillo',
#   'user_org': 'Bitergia',
#   'uuid': '4a8f9d6633149d1d2433362bec4e3a3e97fd2904'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Alberto Martín',
#   'closed_at': '2017-12-11T19:22:20Z',
#   'created_at': '2017-12-05T09:38:37Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2017-12-05T09:38:37+00:00',
#   'id': 279306369,
#   'id_in_repo': '244',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'bug;;meetup;;',
#   'metadata__enriched_on': '2018-03-04T17:36:35.687124',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:44:56.834237+00:00',
#   'metadata__updated_on': '2018-02-13T23:12:19+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 6.41,
#   'time_to_close_days': 6.41,
#   'title': '[meetup] Negative sleep length',
#   'title_analyzed': '[meetup] Negative sleep length',
#   'updated_at': '2018-02-13T23:12:19Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/244',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/244',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': 'Madrid',
#   'user_login': 'albertinisg',
#   'user_name': 'Alberto Martín',
#   'user_org': '@Bitergia ',
#   'uuid': '52fb25adc71aff2d948a7287e1b7a7bec6db1643'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'Santiago Dueñas',
#   'closed_at': '2018-02-20T12:12:12Z',
#   'created_at': '2018-02-20T11:47:11Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2018-02-20T11:47:11+00:00',
#   'id': 298564842,
#   'id_in_repo': '330',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:36.308165',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:45:13.196601+00:00',
#   'metadata__updated_on': '2018-02-20T12:12:12+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'closed',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 0.02,
#   'time_to_close_days': 0.02,
#   'title': 'Handle archive errors',
#   'title_analyzed': 'Handle archive errors',
#   'updated_at': '2018-02-20T12:12:12Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/330',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/330',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'sduenas',
#   'user_name': 'Santiago Dueñas',
#   'user_org': None,
#   'uuid': '46551ddd3ec22396a44aa153d08067a72111aca8'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': None,
#   'closed_at': None,
#   'created_at': '2018-02-21T06:13:04Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2018-02-21T06:13:04+00:00',
#   'id': 298853432,
#   'id_in_repo': '331',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:36.310077',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:45:19.033361+00:00',
#   'metadata__updated_on': '2018-02-28T12:32:23+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 11.47,
#   'time_to_close_days': None,
#   'title': 'successfully installed perceval 0.9.10 on a Windows machine, but '
#            'perceval  is not recognized as a command on the command prompt',
#   'title_analyzed': 'successfully installed perceval 0.9.10 on a Windows '
#                     'machine, but perceval  is not recognized as a command on '
#                     'the command prompt',
#   'updated_at': '2018-02-28T12:32:23Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/331',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/331',
#   'user_email': None,
#   'user_geolocation': None,
#   'user_location': None,
#   'user_login': 'kk-gndu',
#   'user_name': None,
#   'user_org': None,
#   'uuid': '83c882db5590007e586b2217e290ee16b6eb3544'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': None,
#   'created_at': '2018-03-01T09:45:12Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2018-03-01T09:45:12+00:00',
#   'id': 301338299,
#   'id_in_repo': '335',
#   'is_github_issue': 1,
#   'item_type': 'issue',
#   'labels': 'enhancement;;',
#   'metadata__enriched_on': '2018-03-04T17:36:36.310477',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:45:21.058191+00:00',
#   'metadata__updated_on': '2018-03-01T10:13:29+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': False,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 3.33,
#   'time_to_close_days': None,
#   'title': 'Check valid categories for backends',
#   'title_analyzed': 'Check valid categories for backends',
#   'updated_at': '2018-03-01T10:13:29Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/issues/335',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/335',
#   'user_domain': 'bitergia.com',
#   'user_email': 'valcos@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'valeriocos',
#   'user_name': 'valerio',
#   'user_org': '@Bitergia ',
#   'uuid': 'b8a026cf7b73a611abe1a0d48a9400e291cbf287'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': None,
#   'created_at': '2018-03-03T02:44:07Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2018-03-03T02:44:07+00:00',
#   'id': 301961020,
#   'id_in_repo': '338',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:36.312331',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:45:26.104765+00:00',
#   'metadata__updated_on': '2018-03-03T02:46:20+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 1.62,
#   'time_to_close_days': None,
#   'title': '[stackexchange] Add default parameters',
#   'title_analyzed': '[stackexchange] Add default parameters',
#   'updated_at': '2018-03-03T02:46:20Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/338',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/338',
#   'user_domain': 'bitergia.com',
#   'user_email': 'valcos@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'valeriocos',
#   'user_name': 'valerio',
#   'user_org': '@Bitergia ',
#   'uuid': '22c817f02dc04744aee7760484e3b6a54f27ba85'},
#  {'assignee_domain': None,
#   'assignee_email': None,
#   'assignee_geolocation': None,
#   'assignee_location': None,
#   'assignee_login': None,
#   'assignee_name': None,
#   'assignee_org': None,
#   'author_name': 'valerio',
#   'closed_at': None,
#   'created_at': '2018-03-03T02:48:50Z',
#   'github_repo': 'chaoss/grimoirelab-perceval',
#   'grimoire_creation_date': '2018-03-03T02:48:50+00:00',
#   'id': 301961382,
#   'id_in_repo': '342',
#   'is_github_issue': 1,
#   'item_type': 'pull request',
#   'labels': '',
#   'metadata__enriched_on': '2018-03-04T17:36:36.313977',
#   'metadata__gelk_backend_name': 'GitHubEnrich',
#   'metadata__gelk_version': '0.30.23',
#   'metadata__timestamp': '2018-03-04T01:45:29.767042+00:00',
#   'metadata__updated_on': '2018-03-03T02:52:50+00:00',
#   'offset': None,
#   'origin': 'https://github.com/grimoirelab/perceval',
#   'pull_request': True,
#   'repository': 'https://github.com/chaoss/grimoirelab-perceval',
#   'state': 'open',
#   'tag': 'https://github.com/grimoirelab/perceval',
#   'time_open_days': 1.62,
#   'time_to_close_days': None,
#   'title': '[mediawiki] Force sort request payload parameters',
#   'title_analyzed': '[mediawiki] Force sort request payload parameters',
#   'updated_at': '2018-03-03T02:52:50Z',
#   'url': 'https://github.com/chaoss/grimoirelab-perceval/pull/342',
#   'url_id': 'chaoss/grimoirelab-perceval/issues/342',
#   'user_domain': 'bitergia.com',
#   'user_email': 'valcos@bitergia.com',
#   'user_geolocation': None,
#   'user_location': 'Madrid, Spain',
#   'user_login': 'valeriocos',
#   'user_name': 'valerio',
#   'user_org': '@Bitergia ',
#   'uuid': '6469932cb85d967bca1f46b63748436d7f3c7839'}]

# %%
request=Search(using=es ,index=enriched_index)
repo_data=[]

request = request.sort({'created_at':{'order':'desc'}})
#s = s.sort({'created_at': { 'order' : 'asc'}})
request = request.filter("terms", item_type = ['issue'])
request = request.filter('range', created_at ={'gte': 'now-6M'})
request = request.source(['id', 'closed_at', 'created_at','time_open_days','time_to_close_days']) 
request = request[0:100]
s = request.execute()

for x in s :
    if(x.time_to_close_days == None):
        x.time_to_close_days = 'NA'
        x.closed_at = 'Issue still open'
    repo_data.append({'issue_id':x.id ,'time_open_days':x.time_open_days,'time_to_close_days':x.time_to_close_days,
                     'created_at':x.created_at,'closed_at':x.closed_at})
pprint ((repo_data))
# Out:
# [{'closed_at': 'Issue still open',
#   'created_at': '2018-03-02T18:22:45Z',
#   'issue_id': 301859388,
#   'time_open_days': 1.97,
#   'time_to_close_days': 'NA'},
#  {'closed_at': 'Issue still open',
#   'created_at': '2018-03-01T09:45:12Z',
#   'issue_id': 301338299,
#   'time_open_days': 3.33,
#   'time_to_close_days': 'NA'},
#  {'closed_at': 'Issue still open',
#   'created_at': '2018-02-21T06:13:04Z',
#   'issue_id': 298853432,
#   'time_open_days': 11.47,
#   'time_to_close_days': 'NA'},
#  {'closed_at': '2018-02-19T23:48:50Z',
#   'created_at': '2018-02-19T11:03:51Z',
#   'issue_id': 298235932,
#   'time_open_days': 0.53,
#   'time_to_close_days': 0.53},
#  {'closed_at': '2018-02-19T10:02:53Z',
#   'created_at': '2018-02-17T08:56:30Z',
#   'issue_id': 297990762,
#   'time_open_days': 2.05,
#   'time_to_close_days': 2.05},
#  {'closed_at': 'Issue still open',
#   'created_at': '2018-02-15T08:37:18Z',
#   'issue_id': 297364923,
#   'time_open_days': 17.37,
#   'time_to_close_days': 'NA'},
#  {'closed_at': 'Issue still open',
#   'created_at': '2018-02-14T08:57:59Z',
#   'issue_id': 297018141,
#   'time_open_days': 18.36,
#   'time_to_close_days': 'NA'},
#  {'closed_at': 'Issue still open',
#   'created_at': '2018-02-09T16:29:36Z',
#   'issue_id': 295929758,
#   'time_open_days': 23.05,
#   'time_to_close_days': 'NA'},
#  {'closed_at': 'Issue still open',
#   'created_at': '2018-02-09T15:33:40Z',
#   'issue_id': 295910162,
#   'time_open_days': 23.09,
#   'time_to_close_days': 'NA'},
#  {'closed_at': '2018-01-29T16:15:00Z',
#   'created_at': '2018-01-26T12:51:35Z',
#   'issue_id': 291892484,
#   'time_open_days': 3.14,
#   'time_to_close_days': 3.14},
#  {'closed_at': '2018-02-12T10:50:22Z',
#   'created_at': '2018-01-17T06:35:40Z',
#   'issue_id': 289157168,
#   'time_open_days': 26.18,
#   'time_to_close_days': 26.18},
#  {'closed_at': '2018-01-15T10:55:18Z',
#   'created_at': '2018-01-06T20:11:19Z',
#   'issue_id': 286514442,
#   'time_open_days': 8.61,
#   'time_to_close_days': 8.61},
#  {'closed_at': '2017-12-27T10:39:03Z',
#   'created_at': '2017-12-27T10:32:00Z',
#   'issue_id': 284695994,
#   'time_open_days': 0.0,
#   'time_to_close_days': 0.0},
#  {'closed_at': '2017-12-27T17:04:56Z',
#   'created_at': '2017-12-26T19:13:19Z',
#   'issue_id': 284598380,
#   'time_open_days': 0.91,
#   'time_to_close_days': 0.91},
#  {'closed_at': '2018-01-02T13:56:41Z',
#   'created_at': '2017-12-26T11:41:57Z',
#   'issue_id': 284542963,
#   'time_open_days': 7.09,
#   'time_to_close_days': 7.09},
#  {'closed_at': '2017-12-27T17:34:50Z',
#   'created_at': '2017-12-22T15:27:08Z',
#   'issue_id': 284188761,
#   'time_open_days': 5.09,
#   'time_to_close_days': 5.09},
#  {'closed_at': '2017-12-26T15:45:10Z',
#   'created_at': '2017-12-21T21:34:00Z',
#   'issue_id': 284010751,
#   'time_open_days': 4.76,
#   'time_to_close_days': 4.76},
#  {'closed_at': '2017-12-18T16:22:17Z',
#   'created_at': '2017-12-18T11:39:22Z',
#   'issue_id': 282849839,
#   'time_open_days': 0.2,
#   'time_to_close_days': 0.2},
#  {'closed_at': '2017-12-18T10:47:29Z',
#   'created_at': '2017-12-15T08:55:13Z',
#   'issue_id': 282358689,
#   'time_open_days': 3.08,
#   'time_to_close_days': 3.08},
#  {'closed_at': '2017-12-11T12:59:45Z',
#   'created_at': '2017-12-05T10:28:42Z',
#   'issue_id': 279322423,
#   'time_open_days': 6.1,
#   'time_to_close_days': 6.1},
#  {'closed_at': '2017-12-11T19:22:20Z',
#   'created_at': '2017-12-05T09:38:37Z',
#   'issue_id': 279306369,
#   'time_open_days': 6.41,
#   'time_to_close_days': 6.41},
#  {'closed_at': '2017-12-13T16:06:25Z',
#   'created_at': '2017-12-05T08:26:47Z',
#   'issue_id': 279286233,
#   'time_open_days': 8.32,
#   'time_to_close_days': 8.32},
#  {'closed_at': '2018-01-02T15:14:59Z',
#   'created_at': '2017-12-01T12:46:47Z',
#   'issue_id': 278456013,
#   'time_open_days': 32.1,
#   'time_to_close_days': 32.1},
#  {'closed_at': 'Issue still open',
#   'created_at': '2017-12-01T09:29:35Z',
#   'issue_id': 278406312,
#   'time_open_days': 93.34,
#   'time_to_close_days': 'NA'},
#  {'closed_at': 'Issue still open',
#   'created_at': '2017-11-30T17:40:49Z',
#   'issue_id': 278208899,
#   'time_open_days': 94.0,
#   'time_to_close_days': 'NA'},
#  {'closed_at': '2017-11-30T09:34:39Z',
#   'created_at': '2017-11-29T16:59:29Z',
#   'issue_id': 277831242,
#   'time_open_days': 0.69,
#   'time_to_close_days': 0.69},
#  {'closed_at': 'Issue still open',
#   'created_at': '2017-11-28T10:48:43Z',
#   'issue_id': 277338705,
#   'time_open_days': 96.28,
#   'time_to_close_days': 'NA'},
#  {'closed_at': '2017-11-28T17:18:41Z',
#   'created_at': '2017-11-28T10:47:58Z',
#   'issue_id': 277338465,
#   'time_open_days': 0.27,
#   'time_to_close_days': 0.27},
#  {'closed_at': '2017-11-22T13:05:37Z',
#   'created_at': '2017-11-22T11:02:39Z',
#   'issue_id': 276026925,
#   'time_open_days': 0.09,
#   'time_to_close_days': 0.09},
#  {'closed_at': '2018-02-05T09:52:30Z',
#   'created_at': '2017-11-15T22:00:07Z',
#   'issue_id': 274319547,
#   'time_open_days': 81.49,
#   'time_to_close_days': 81.49},
#  {'closed_at': '2017-11-08T12:01:53Z',
#   'created_at': '2017-11-08T11:54:07Z',
#   'issue_id': 272171796,
#   'time_open_days': 0.01,
#   'time_to_close_days': 0.01},
#  {'closed_at': '2017-11-17T13:32:17Z',
#   'created_at': '2017-11-08T10:33:36Z',
#   'issue_id': 272149295,
#   'time_open_days': 9.12,
#   'time_to_close_days': 9.12},
#  {'closed_at': '2017-11-14T12:11:32Z',
#   'created_at': '2017-11-08T10:04:09Z',
#   'issue_id': 272140223,
#   'time_open_days': 6.09,
#   'time_to_close_days': 6.09},
#  {'closed_at': '2017-11-09T12:03:24Z',
#   'created_at': '2017-11-07T16:39:34Z',
#   'issue_id': 271900732,
#   'time_open_days': 1.81,
#   'time_to_close_days': 1.81},
#  {'closed_at': '2017-11-08T11:38:22Z',
#   'created_at': '2017-11-07T09:45:32Z',
#   'issue_id': 271767324,
#   'time_open_days': 1.08,
#   'time_to_close_days': 1.08},
#  {'closed_at': '2017-11-15T14:00:31Z',
#   'created_at': '2017-10-30T23:09:47Z',
#   'issue_id': 269783537,
#   'time_open_days': 15.62,
#   'time_to_close_days': 15.62},
#  {'closed_at': '2017-10-25T08:09:05Z',
#   'created_at': '2017-10-24T19:27:29Z',
#   'issue_id': 268156760,
#   'time_open_days': 0.53,
#   'time_to_close_days': 0.53},
#  {'closed_at': '2017-11-08T18:46:02Z',
#   'created_at': '2017-10-16T17:34:48Z',
#   'issue_id': 265852168,
#   'time_open_days': 23.05,
#   'time_to_close_days': 23.05},
#  {'closed_at': '2017-10-25T17:41:25Z',
#   'created_at': '2017-10-16T13:33:20Z',
#   'issue_id': 265771715,
#   'time_open_days': 9.17,
#   'time_to_close_days': 9.17},
#  {'closed_at': '2017-10-30T10:15:59Z',
#   'created_at': '2017-10-16T10:48:08Z',
#   'issue_id': 265725970,
#   'time_open_days': 13.98,
#   'time_to_close_days': 13.98},
#  {'closed_at': '2017-10-16T19:13:11Z',
#   'created_at': '2017-10-11T12:24:04Z',
#   'issue_id': 264565701,
#   'time_open_days': 5.28,
#   'time_to_close_days': 5.28},
#  {'closed_at': '2017-10-24T12:30:36Z',
#   'created_at': '2017-10-09T18:22:00Z',
#   'issue_id': 263984345,
#   'time_open_days': 14.76,
#   'time_to_close_days': 14.76},
#  {'closed_at': '2017-10-10T14:27:30Z',
#   'created_at': '2017-10-09T16:20:16Z',
#   'issue_id': 263951843,
#   'time_open_days': 0.92,
#   'time_to_close_days': 0.92},
#  {'closed_at': 'Issue still open',
#   'created_at': '2017-09-27T11:44:00Z',
#   'issue_id': 260943749,
#   'time_open_days': 158.24,
#   'time_to_close_days': 'NA'},
#  {'closed_at': '2017-09-29T17:21:43Z',
#   'created_at': '2017-09-26T15:04:45Z',
#   'issue_id': 260659564,
#   'time_open_days': 3.1,
#   'time_to_close_days': 3.1},
#  {'closed_at': '2017-11-07T12:07:50Z',
#   'created_at': '2017-09-25T21:02:07Z',
#   'issue_id': 260413900,
#   'time_open_days': 42.63,
#   'time_to_close_days': 42.63},
#  {'closed_at': '2017-09-27T11:24:36Z',
#   'created_at': '2017-09-22T04:45:33Z',
#   'issue_id': 259701686,
#   'time_open_days': 5.28,
#   'time_to_close_days': 5.28},
#  {'closed_at': 'Issue still open',
#   'created_at': '2017-09-19T21:52:22Z',
#   'issue_id': 258975927,
#   'time_open_days': 165.82,
#   'time_to_close_days': 'NA'},
#  {'closed_at': '2017-10-07T14:41:19Z',
#   'created_at': '2017-09-13T10:01:38Z',
#   'issue_id': 257324459,
#   'time_open_days': 24.19,
#   'time_to_close_days': 24.19},
#  {'closed_at': '2017-09-15T08:45:58Z',
#   'created_at': '2017-09-13T09:55:38Z',
#   'issue_id': 257322632,
#   'time_open_days': 1.95,
#   'time_to_close_days': 1.95}]

# %%
df = pd.DataFrame(repo_data, columns=["issue_id","time_open_days","time_to_close_days","created_at","closed_at"])
df
# Out:
#      issue_id  time_open_days time_to_close_days            created_at  \
# 0   301859388            1.97                 NA  2018-03-02T18:22:45Z
# 1   301338299            3.33                 NA  2018-03-01T09:45:12Z
# 2   298853432           11.47                 NA  2018-02-21T06:13:04Z
# 3   298235932            0.53               0.53  2018-02-19T11:03:51Z
# 4   297990762            2.05               2.05  2018-02-17T08:56:30Z
# 5   297364923           17.37                 NA  2018-02-15T08:37:18Z
# 6   297018141           18.36                 NA  2018-02-14T08:57:59Z
# 7   295929758           23.05                 NA  2018-02-09T16:29:36Z
# 8   295910162           23.09                 NA  2018-02-09T15:33:40Z
# 9   291892484            3.14               3.14  2018-01-26T12:51:35Z
# 10  289157168           26.18              26.18  2018-01-17T06:35:40Z
# 11  286514442            8.61               8.61  2018-01-06T20:11:19Z
# 12  284695994            0.00                  0  2017-12-27T10:32:00Z
# 13  284598380            0.91               0.91  2017-12-26T19:13:19Z
# 14  284542963            7.09               7.09  2017-12-26T11:41:57Z
# 15  284188761            5.09               5.09  2017-12-22T15:27:08Z
# 16  284010751            4.76               4.76  2017-12-21T21:34:00Z
# 17  282849839            0.20                0.2  2017-12-18T11:39:22Z
# 18  282358689            3.08               3.08  2017-12-15T08:55:13Z
# 19  279322423            6.10                6.1  2017-12-05T10:28:42Z
# 20  279306369            6.41               6.41  2017-12-05T09:38:37Z
# 21  279286233            8.32               8.32  2017-12-05T08:26:47Z
# 22  278456013           32.10               32.1  2017-12-01T12:46:47Z
# 23  278406312           93.34                 NA  2017-12-01T09:29:35Z
# 24  278208899           94.00                 NA  2017-11-30T17:40:49Z
# 25  277831242            0.69               0.69  2017-11-29T16:59:29Z
# 26  277338705           96.28                 NA  2017-11-28T10:48:43Z
# 27  277338465            0.27               0.27  2017-11-28T10:47:58Z
# 28  276026925            0.09               0.09  2017-11-22T11:02:39Z
# 29  274319547           81.49              81.49  2017-11-15T22:00:07Z
# 30  272171796            0.01               0.01  2017-11-08T11:54:07Z
# 31  272149295            9.12               9.12  2017-11-08T10:33:36Z
# 32  272140223            6.09               6.09  2017-11-08T10:04:09Z
# 33  271900732            1.81               1.81  2017-11-07T16:39:34Z
# 34  271767324            1.08               1.08  2017-11-07T09:45:32Z
# 35  269783537           15.62              15.62  2017-10-30T23:09:47Z
# 36  268156760            0.53               0.53  2017-10-24T19:27:29Z
# 37  265852168           23.05              23.05  2017-10-16T17:34:48Z
# 38  265771715            9.17               9.17  2017-10-16T13:33:20Z
# 39  265725970           13.98              13.98  2017-10-16T10:48:08Z
# 40  264565701            5.28               5.28  2017-10-11T12:24:04Z
# 41  263984345           14.76              14.76  2017-10-09T18:22:00Z
# 42  263951843            0.92               0.92  2017-10-09T16:20:16Z
# 43  260943749          158.24                 NA  2017-09-27T11:44:00Z
# 44  260659564            3.10                3.1  2017-09-26T15:04:45Z
# 45  260413900           42.63              42.63  2017-09-25T21:02:07Z
# 46  259701686            5.28               5.28  2017-09-22T04:45:33Z
# 47  258975927          165.82                 NA  2017-09-19T21:52:22Z
# 48  257324459           24.19              24.19  2017-09-13T10:01:38Z
# 49  257322632            1.95               1.95  2017-09-13T09:55:38Z
#
#                closed_at
# 0       Issue still open
# 1       Issue still open
# 2       Issue still open
# 3   2018-02-19T23:48:50Z
# 4   2018-02-19T10:02:53Z
# 5       Issue still open
# 6       Issue still open
# 7       Issue still open
# 8       Issue still open
# 9   2018-01-29T16:15:00Z
# 10  2018-02-12T10:50:22Z
# 11  2018-01-15T10:55:18Z
# 12  2017-12-27T10:39:03Z
# 13  2017-12-27T17:04:56Z
# 14  2018-01-02T13:56:41Z
# 15  2017-12-27T17:34:50Z
# 16  2017-12-26T15:45:10Z
# 17  2017-12-18T16:22:17Z
# 18  2017-12-18T10:47:29Z
# 19  2017-12-11T12:59:45Z
# 20  2017-12-11T19:22:20Z
# 21  2017-12-13T16:06:25Z
# 22  2018-01-02T15:14:59Z
# 23      Issue still open
# 24      Issue still open
# 25  2017-11-30T09:34:39Z
# 26      Issue still open
# 27  2017-11-28T17:18:41Z
# 28  2017-11-22T13:05:37Z
# 29  2018-02-05T09:52:30Z
# 30  2017-11-08T12:01:53Z
# 31  2017-11-17T13:32:17Z
# 32  2017-11-14T12:11:32Z
# 33  2017-11-09T12:03:24Z
# 34  2017-11-08T11:38:22Z
# 35  2017-11-15T14:00:31Z
# 36  2017-10-25T08:09:05Z
# 37  2017-11-08T18:46:02Z
# 38  2017-10-25T17:41:25Z
# 39  2017-10-30T10:15:59Z
# 40  2017-10-16T19:13:11Z
# 41  2017-10-24T12:30:36Z
# 42  2017-10-10T14:27:30Z
# 43      Issue still open
# 44  2017-09-29T17:21:43Z
# 45  2017-11-07T12:07:50Z
# 46  2017-09-27T11:24:36Z
# 47      Issue still open
# 48  2017-10-07T14:41:19Z
# 49  2017-09-15T08:45:58Z

# %%
import numpy as np

# data to plot
n = 20
ids=[]
close_days=[]
open_days=[]
for x in range(n):
    ids.append(repo_data[x]['issue_id'])
    if(repo_data[x]['time_to_close_days']=='NA'):
        repo_data[x]['time_to_close_days']=0
    close_days.append(repo_data[x]['time_open_days'])
    open_days.append(repo_data[x]['time_to_close_days'])

 
# create plot
fig=plt.figure(figsize=(15,10))

index = np.arange(n)
bar_width = 0.2
opacity = 0.8
rects1 = plt.bar(index+ bar_width/2 , close_days, bar_width,
                 alpha=opacity,
                 color='blue',
                 label='time_to_close_days')
 
rects2 = plt.bar(index + bar_width +bar_width/2 , open_days, bar_width,
                 alpha=opacity,
                 color='orange',
                 label='time_open_days')
plt.xlabel('Issue Id',fontsize=12)
plt.ylabel('Days',fontsize=12)
plt.title('Issues in last 6 months',fontsize=12)
plt.xticks(index + bar_width, ids,fontsize=8,rotation=45)
plt.legend()

plt.show()
